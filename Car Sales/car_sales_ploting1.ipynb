# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./Car_sales (4).csv', parse_dates=['Latest_Launch'])

# %%
data.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
# 9          BMW     528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    datetime64[ns]
# ...

# %%
data.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
data.isnull().mean()*100
# Out:
# Manufacturer            0.000000
# Model                   0.000000
# Sales_in_thousands      0.000000
# __year_resale_value    22.929936
# Vehicle_type            0.000000
# Price_in_thousands      1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Wheelbase               0.636943
# Width                   0.636943
# Length                  0.636943
# Curb_weight             1.273885
# Fuel_capacity           0.636943
# Fuel_efficiency         1.910828
# Latest_Launch           0.000000
# Power_perf_factor       1.273885
# dtype: float64

# %%
data.shape
# Out:
# (157, 16)

# %%
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (117, 16)

# %%
data.sort_values(by='Latest_Launch')
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 90       Mercury    Mountaineer              27.609               20.430
# 91       Mercury       Villager              20.380               14.795
# 131       Saturn             SW               5.223               10.790
# 145   Volkswagen           Golf               9.761               11.425
# 137       Toyota          Camry             247.994               13.245
# ..           ...            ...                 ...                  ...
# 80    Mitsubishi        Eclipse              42.541               10.395
# 119      Pontiac       Grand Am             131.097               10.290
# 86       Mercury       Mystique              14.351                8.800
# 125      Porsche  Carrera Coupe               1.280               60.625
# 139       Toyota         Celica              33.269               15.445
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.reset_index(inplace=True, drop=True)

# %%
data.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       RL               8.588               29.725    Passenger
# 3         Audi       A4              20.397               22.255    Passenger
# 4         Audi       A6              18.780               23.555    Passenger
# 5         Audi       A8               1.380               39.000    Passenger
# 6          BMW     328i               9.231               28.675    Passenger
# 7          BMW     528i              17.527               36.125    Passenger
# 8        Buick  Century              91.561               12.475    Passenger
# 9        Buick    Regal              39.350               13.740    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
data.sort_values(by='Sales_in_thousands',ascending=False)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 46          Ford       F-Series             540.561               15.075
# 42          Ford       Explorer             276.747               16.640
# 105       Toyota          Camry             247.994               13.245
# 40          Ford         Taurus             245.815               10.055
# 48         Honda         Accord             230.902               13.210
# ..           ...            ...                 ...                  ...
# 5           Audi             A8               1.380               39.000
# 99       Porsche  Carrera Coupe               1.280               60.625
# 86    Oldsmobile        Cutlass               1.112               11.240
# 31         Dodge          Viper               0.916               58.470
# 68    Mitsubishi         3000GT               0.110               20.940
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# # Univariate Analysis

# %%
#Histogram

# %%
data.Sales_in_thousands.plot.hist(cmap='rainbow');

# %% [markdown]
# # box plot

# %%
data.Sales_in_thousands.plot.box(cmap ='magma');

# %% [markdown]
# # Kernel Density Estimation Plot (KDE PLOT)

# %%
data.Sales_in_thousands.plot.kde(cmap = 'flag');

# %% [markdown]
# # Sub plots

# %%
data.plot.box( figsize=(18,3), subplots = True);

# %%
data.plot.hist( figsize=(6,12), subplots = True);
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data.plot.box(figsize = (22,5),subplots = True);

# %%
data.plot.kde(figsize = (5,15),subplots = True);
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4016\2455546528.py in <module>
# ----> 1 data.plot.kde(figsize = (5,15),subplots = True);
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in kde(self, bw_method, ind, **kwargs)
#    1452             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1453         """
# -> 1454         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1455
#    1456     density = kde
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %%
data.plot.line(x='__year_resale_value', y='Price_in_thousands', cmap = 'flag')
# Out:
# <AxesSubplot:xlabel='__year_resale_value'>

# %%
data.sort_values(by='__year_resale_value').plot.line(x='__year_resale_value', y='Price_in_thousands', cmap = 'flag')
# Out:
# <AxesSubplot:xlabel='__year_resale_value'>

# %%
data.plot.bar(x='Manufacturer', y='Sales_in_thousands', figsize = (20, 5),cmap= 'magma')
# Out:
# <AxesSubplot:xlabel='Manufacturer'>

# %% [markdown]
# # Count plot

# %%
data.Manufacturer.value_counts().plot.bar(figsize=(12,5), cmap = 'Paired');

# %%
data.Manufacturer.value_counts()
# Out:
# Ford          10
# Dodge          9
# Chevrolet      8
# Toyota         8
# Mitsubishi     7
# Mercury        6
# Chrysler       5
# Honda          5
# Pontiac        5
# Nissan         5
# Volkswagen     5
# Mercedes-B     4
# Oldsmobile     4
# Buick          4
# Saturn         3
# Porsche        3
# Plymouth       3
# Acura          3
# Audi           3
# Jeep           3
# Hyundai        3
# Cadillac       3
# Lexus          3
# Lincoln        2
# BMW            2
# Infiniti       1
# Name: Manufacturer, dtype: int64

# %% [markdown]
# # Area chart

# %%
data.plot.area(x='Manufacturer', y='Sales_in_thousands', figsize = (10,6), cmap='Paired');

# %% [markdown]
# # Horizontal bar chart

# %%
data.sort_values(by='Price_in_thousands')[:5].plot.barh(x='Model', y= 'Power_perf_factor')
# Out:
# <AxesSubplot:ylabel='Model'>

# %%
data.sort_values(by='Price_in_thousands')
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 22     Chevrolet           Metro              21.855                5.160
# 52       Hyundai          Accent              41.184                5.860
# 101       Saturn              SL              80.620                9.200
# 108       Toyota          Tacoma              84.087                9.575
# 53       Hyundai         Elantra              66.692                7.825
# ..           ...             ...                 ...                  ...
# 79    Mercedes-B         S-Class              16.774               50.375
# 31         Dodge           Viper               0.916               58.470
# 99       Porsche   Carrera Coupe               1.280               60.625
# 100      Porsche  Carrera Cabrio               1.866               67.550
# 80    Mercedes-B        SL-Class               3.311               58.600
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# # Scatter plot

# %%
data.sort_values(by='Price_in_thousands')[:5].plot.scatter(x='Latest_Launch', y="Price_in_thousands")
# Out:
# <AxesSubplot:xlabel='Latest_Launch', ylabel='Price_in_thousands'>

# %% [markdown]
# # Pie chart

# %%
data.Vehicle_type.value_counts().plot.pie();

# %%
data.Vehicle_type.value_counts().plot.pie(autopct ='%1.2f%%', legend = True);

# %% [markdown]
# # Hexbin plot

# %%
data.plot.hexbin('Sales_in_thousands', 'Engine_size');

# %%
data.plot.hexbin('Curb_weight', 'Fuel_capacity', gridsize=25);

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       RL               8.588               29.725
# 3           Audi       A4              20.397               22.255
# 4           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 112   Volkswagen     Golf               9.761               11.425
# 113   Volkswagen    Jetta              83.721               13.240
# 114   Volkswagen   Passat              51.102               16.725
# 115   Volkswagen   Cabrio               9.569               16.575
# 116   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
Manufacturer_Sales=data.groupby(['Manufacturer'])['Sales_in_thousands'].sum()

# %%
Manufacturer_Sales.plot.bar();

# %%
Vehicle_type_Sales=data.groupby(['Vehicle_type'])['Sales_in_thousands'].sum()
Vehicle_type_Sales
# Out:
# Vehicle_type
# Car          2766.779
# Passenger    4149.362
# Name: Sales_in_thousands, dtype: float64

# %%
Vehicle_type_Sales.plot.pie()
# Out:
# <AxesSubplot:ylabel='Sales_in_thousands'>
