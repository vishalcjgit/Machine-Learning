# %% [markdown]
# ## Players data set (football players)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./players.csv')

# %%
data.columns
# Out:
# Index(['player_id', 'first_name', 'last_name', 'name', 'last_season',
#        'current_club_id', 'player_code', 'country_of_birth', 'city_of_birth',
#        'country_of_citizenship', 'date_of_birth', 'sub_position', 'position',
#        'foot', 'height_in_cm', 'market_value_in_eur',
#        'highest_market_value_in_eur', 'contract_expiration_date', 'agent_name',
#        'image_url', 'url', 'current_club_domestic_competition_id',
#        'current_club_name'],
#       dtype='object')

# %%
data.describe()
# Out:
#           player_id   last_season  current_club_id  height_in_cm  \
# count  2.945500e+04  29455.000000     29455.000000  27428.000000
# mean   3.024437e+05   2018.409268      4212.177016    182.210806
# std    2.438728e+05      3.386006      9685.655005      6.826261
# min    1.000000e+01   2012.000000         3.000000     18.000000
# 25%    9.246100e+04   2016.000000       398.000000    178.000000
# 50%    2.510700e+05   2019.000000      1053.000000    182.000000
# 75%    4.543285e+05   2022.000000      2999.000000    187.000000
# max    1.143823e+06   2022.000000     83678.000000    207.000000
#
#        market_value_in_eur  highest_market_value_in_eur
# count         1.855100e+04                 2.811500e+04
# mean          2.210902e+06                 3.577479e+06
# std           7.209196e+06                 9.327968e+06
# min           1.000000e+04                 1.000000e+04
# 25%           1.750000e+05                 2.500000e+05
# ...

# %%
#1 head() fun for first 5 rows
data.head()
# Out:
#    player_id first_name   last_name              name  last_season  \
# 0        598       Timo  Hildebrand   Timo Hildebrand         2014
# 1        670     Martin      Petrov     Martin Petrov         2012
# 2       1323     Martin     Amedick    Martin Amedick         2012
# 3       3195   Jermaine     Pennant  Jermaine Pennant         2013
# 4       3259     Damien        Duff       Damien Duff         2013
#
#    current_club_id       player_code country_of_birth city_of_birth  \
# 0               24   timo-hildebrand          Germany         Worms
# 1              714     martin-petrov         Bulgaria        Vratsa
# 2               24    martin-amedick          Germany     Paderborn
# 3              512  jermaine-pennant          England    Nottingham
# 4              931       damien-duff          Ireland    Ballyboden
#
#   country_of_citizenship  ...   foot height_in_cm market_value_in_eur  \
# 0                Germany  ...    NaN          NaN                 NaN
# ...

# %%
#2 shape() fun for data size
data.shape
# Out:
# (29455, 23)

# %%
#3 isnull() fun for null value count
data.isnull().sum()
# Out:
# player_id                                   0
# first_name                               1890
# last_name                                   0
# name                                        0
# last_season                                 0
# current_club_id                             0
# player_code                                 0
# country_of_birth                         3293
# city_of_birth                            2115
# country_of_citizenship                   1267
# date_of_birth                              45
# sub_position                              172
# position                                    0
# foot                                     2310
# height_in_cm                             2027
# market_value_in_eur                     10904
# highest_market_value_in_eur              1340
# contract_expiration_date                11495
# agent_name                              14973
# image_url                                   0
# ...

# %%
#4 dropping null values
data.dropna(inplace=True)

# %%
#5 Reset indexing after dropping null value
data.reset_index(drop=True, inplace=True)

# %%
data.shape
# Out:
# (8004, 23)

# %%
#6 drop_duplicates() fun for droping the duplicated rows
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (8004, 23)

# %%
#7 data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8004 entries, 0 to 8003
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             8004 non-null   int64
#  1   first_name                            8004 non-null   object
#  2   last_name                             8004 non-null   object
#  3   name                                  8004 non-null   object
#  4   last_season                           8004 non-null   int64
#  5   current_club_id                       8004 non-null   int64
#  6   player_code                           8004 non-null   object
#  7   country_of_birth                      8004 non-null   object
#  8   city_of_birth                         8004 non-null   object
#  9   country_of_citizenship                8004 non-null   object
#  10  date_of_birth                         8004 non-null   object
# ...

# %%
#8 dropping column
data.drop(columns='player_id', inplace=True)

# %%
data.head()
# Out:
#   first_name last_name             name  last_season  current_club_id  \
# 0    Danijel   Subasic  Danijel Subasic         2019              162
# 1    Daniele   Dessena  Daniele Dessena         2019               19
# 2      Óscar     Trejo      Óscar Trejo         2022              367
# 3      Fabio  Ceravolo   Fabio Ceravolo         2019              130
# 4      Dusan     Tadic      Dusan Tadic         2022              610
#
#        player_code   country_of_birth        city_of_birth  \
# 0  danijel-subasic  Jugoslawien (SFR)                Zadar
# 1  daniele-dessena              Italy                Parma
# 2      oscar-trejo          Argentina  Santiago del Estero
# 3   fabio-ceravolo              Italy                Locri
# 4      dusan-tadic  Jugoslawien (SFR)         Bačka Topola
#
#   country_of_citizenship date_of_birth  ...   foot height_in_cm  \
# 0                Croatia    1984-10-27  ...  right        191.0
# ...

# %%
#9
data.drop(columns='first_name', inplace=True)
data.drop(columns='last_name', inplace=True)

# %%
data.head()
# Out:
#               name  last_season  current_club_id      player_code  \
# 0  Danijel Subasic         2019              162  danijel-subasic
# 1  Daniele Dessena         2019               19  daniele-dessena
# 2      Óscar Trejo         2022              367      oscar-trejo
# 3   Fabio Ceravolo         2019              130   fabio-ceravolo
# 4      Dusan Tadic         2022              610      dusan-tadic
#
#     country_of_birth        city_of_birth country_of_citizenship  \
# 0  Jugoslawien (SFR)                Zadar                Croatia
# 1              Italy                Parma                  Italy
# 2          Argentina  Santiago del Estero              Argentina
# 3              Italy                Locri                  Italy
# 4  Jugoslawien (SFR)         Bačka Topola                 Serbia
#
#   date_of_birth        sub_position    position   foot  height_in_cm  \
# 0    1984-10-27          Goalkeeper  Goalkeeper  right         191.0
# ...

# %%
#10 column names

# %%
data.columns
# Out:
# Index(['name', 'last_season', 'current_club_id', 'player_code',
#        'country_of_birth', 'city_of_birth', 'country_of_citizenship',
#        'date_of_birth', 'sub_position', 'position', 'foot', 'height_in_cm',
#        'market_value_in_eur', 'highest_market_value_in_eur',
#        'contract_expiration_date', 'agent_name', 'image_url', 'url',
#        'current_club_domestic_competition_id', 'current_club_name'],
#       dtype='object')

# %%
#11 total number of countries in "country_of_citizenship" column

# %%
data.country_of_citizenship.nunique()
# Out:
# 145

# %%
#12 country with more number of players(country_of_citizenship)-
# in the given data set

# %%
data.country_of_citizenship.value_counts()
# Out:
# Spain             688
# Italy             526
# Germany           524
# France            469
# England           411
#                  ...
# Southern Sudan      1
# Bolivia             1
# St. Lucia           1
# Grenada             1
# Mozambique          1
# Name: country_of_citizenship, Length: 145, dtype: int64

# %%
#13 total data count of "current_club_name" column

# %%
data.current_club_name.count()
# Out:
# 8004

# %%
#14 total number of clubs in "current_club_name" column

# %%
data.current_club_name.nunique()
# Out:
# 397

# %%
#15 Highest market valued player in the given data set, sort

# %%
data.sort_values(by='highest_market_value_in_eur',ascending=False)
# Out:
#                        name  last_season  current_club_id  \
# 3280         Erling Haaland         2022              281
# 7837             Harry Kane         2022              148
# 4943      Philippe Coutinho         2022              405
# 592              Sadio Mané         2022               27
# 4004      Antoine Griezmann         2022               13
# ...                     ...          ...              ...
# 7013      Chiel Olde Keizer         2021             1304
# 6686         Vincenzo Pinto         2017             4171
# 7529           Timo Jansink         2021             1304
# 3364          Kerian Atheba         2021             3948
# 5292  Massimiliano Mignogna         2020             4083
#
#                 player_code country_of_birth   city_of_birth  \
# 3280         erling-haaland          England           Leeds
# 7837             harry-kane          England          London
# 4943      philippe-coutinho           Brazil  Rio de Janeiro
# ...

# %%
#16 total count of different "positions"

# %%
data.position.value_counts()
# Out:
# Defender      2650
# Midfield      2334
# Attack        2214
# Goalkeeper     806
# Name: position, dtype: int64

# %%
#17 total count of foots

# %%
data.foot.value_counts()
# Out:
# right    5608
# left     2058
# both      338
# Name: foot, dtype: int64

# %%
#18 total number of ENGLAND players

# %%
data.country_of_citizenship.value_counts()
# Out:
# Spain             688
# Italy             526
# Germany           524
# France            469
# England           411
#                  ...
# Southern Sudan      1
# Bolivia             1
# St. Lucia           1
# Grenada             1
# Mozambique          1
# Name: country_of_citizenship, Length: 145, dtype: int64

# %%
#or

# %%
data_query = data.query("country_of_citizenship == 'England'")

# %%
data_query.shape
# Out:
# (411, 20)

# %%
#19 total number of ENGLAND players, playing for MANCHESTER CITY

# %%
data_query2 = data.query("country_of_citizenship == 'England' & current_club_name == 'Manchester City' ")

# %%
data_query2
# Out:
#                      name  last_season  current_club_id          player_code  \
# 350        James Trafford         2020              281       james-trafford
# 681       Daniel Grimshaw         2018              281      daniel-grimshaw
# 1284           Ben Knight         2022              281           ben-knight
# 1291  Josh Wilson-Esbrand         2022              281  josh-wilson-esbrand
# 1537          John Stones         2022              281          john-stones
# 1551        Jack Grealish         2022              281        jack-grealish
# 3291          Tommy Doyle         2021              281          tommy-doyle
# 3373           Liam Delap         2022              281           liam-delap
# 3521         George Evans         2015              281         george-evans
# 3987          Kyle Walker         2022              281          kyle-walker
# 5812         Scott Carson         2022              281         scott-carson
# ...

# %%
data_query2.country_of_citizenship.value_counts()
# Out:
# England    14
# Name: country_of_citizenship, dtype: int64

# %%
#OR
data_query2.shape
# Out:
# (14, 20)

# %%
#display the data from 100 to 150
#20a loc, selecting range of rows from 100 to 150,,,
#,,,This method includes the last element of the range passed in it, unlike iloc().
#missing#range passed in it, unlike iloc().

# %%
data.loc[100:150]
# Out:
#                     name  last_season  current_club_id          player_code  \
# 100         Luka Zahovic         2016              306         luka-zahovic
# 101       Orhan Ovacikli         2020              126       orhan-ovacikli
# 102        Artem Favorov         2019            16239        artem-favorov
# 103          Marius Funk         2021               65          marius-funk
# 104    Nicolas Saint-Ruf         2016              595    nicolas-saint-ruf
# 105          Jack Duncan         2015             5724          jack-duncan
# 106          Ugur Ciftci         2022             2381          ugur-ciftci
# 107         Mikey Devlin         2022              903         mikey-devlin
# 108        Lars Veldwijk         2019              468        lars-veldwijk
# 109         Álex Barrera         2015             2448         alex-barrera
# 110        Julián Cuesta         2022              605        julian-cuesta
# ...

# %%
#20b selecting rage of values from 30 to 70

# %%
data.loc[30:70]
# Out:
#                     name  last_season  current_club_id           player_code  \
# 30          Victor Moses         2022              232          victor-moses
# 31   Alessandro De Vitis         2014             1038   alessandro-de-vitis
# 32           Alan Mannus         2017             2578           alan-mannus
# 33       Aron Gunnarsson         2018              603       aron-gunnarsson
# 34     Bernardo Espinosa         2022            12321     bernardo-espinosa
# 35        Youssef Msakni         2018             1245        youssef-msakni
# 36           David Simão         2022             8024           david-simao
# 37       Vegar Hedenstad         2021             6646       vegar-hedenstad
# 38  Aleksandar Ignjovski         2017               60  aleksandar-ignjovski
# 39         Víctor Ibáñez         2013             3302         victor-ibanez
# 40       Yannick Bolasie         2021              126       yannick-bolasie
# ...

# %%
#21a iloc(first five values/rows using iloc)

# %%
data.iloc[:5]
# Out:
#               name  last_season  current_club_id      player_code  \
# 0  Danijel Subasic         2019              162  danijel-subasic
# 1  Daniele Dessena         2019               19  daniele-dessena
# 2      Óscar Trejo         2022              367      oscar-trejo
# 3   Fabio Ceravolo         2019              130   fabio-ceravolo
# 4      Dusan Tadic         2022              610      dusan-tadic
#
#     country_of_birth        city_of_birth country_of_citizenship  \
# 0  Jugoslawien (SFR)                Zadar                Croatia
# 1              Italy                Parma                  Italy
# 2          Argentina  Santiago del Estero              Argentina
# 3              Italy                Locri                  Italy
# 4  Jugoslawien (SFR)         Bačka Topola                 Serbia
#
#   date_of_birth        sub_position    position   foot  height_in_cm  \
# 0    1984-10-27          Goalkeeper  Goalkeeper  right         191.0
# ...

# %%
data.head()
# Out:
#               name  last_season  current_club_id      player_code  \
# 0  Danijel Subasic         2019              162  danijel-subasic
# 1  Daniele Dessena         2019               19  daniele-dessena
# 2      Óscar Trejo         2022              367      oscar-trejo
# 3   Fabio Ceravolo         2019              130   fabio-ceravolo
# 4      Dusan Tadic         2022              610      dusan-tadic
#
#     country_of_birth        city_of_birth country_of_citizenship  \
# 0  Jugoslawien (SFR)                Zadar                Croatia
# 1              Italy                Parma                  Italy
# 2          Argentina  Santiago del Estero              Argentina
# 3              Italy                Locri                  Italy
# 4  Jugoslawien (SFR)         Bačka Topola                 Serbia
#
#   date_of_birth        sub_position    position   foot  height_in_cm  \
# 0    1984-10-27          Goalkeeper  Goalkeeper  right         191.0
# ...

# %%
data.head(10)
# Out:
#               name  last_season  current_club_id      player_code  \
# 0  Danijel Subasic         2019              162  danijel-subasic
# 1  Daniele Dessena         2019               19  daniele-dessena
# 2      Óscar Trejo         2022              367      oscar-trejo
# 3   Fabio Ceravolo         2019              130   fabio-ceravolo
# 4      Dusan Tadic         2022              610      dusan-tadic
# 5      Aykut Demir         2016             2944      aykut-demir
# 6      Vítor Gomes         2022             2425      vitor-gomes
# 7        Pape Diop         2020             1533        pape-diop
# 8         Joe Hart         2022              371         joe-hart
# 9  Tommaso Bianchi         2013             6574  tommaso-bianchi
#
#     country_of_birth        city_of_birth country_of_citizenship  \
# 0  Jugoslawien (SFR)                Zadar                Croatia
# 1              Italy                Parma                  Italy
# ...

# %%
#21b first 1 value
data.iloc[:1]
# Out:
#               name  last_season  current_club_id      player_code  \
# 0  Danijel Subasic         2019              162  danijel-subasic
#
#     country_of_birth city_of_birth country_of_citizenship date_of_birth  \
# 0  Jugoslawien (SFR)         Zadar                Croatia    1984-10-27
#
#   sub_position    position   foot  height_in_cm  market_value_in_eur  \
# 0   Goalkeeper  Goalkeeper  right         191.0              50000.0
#
#    highest_market_value_in_eur contract_expiration_date agent_name  \
# 0                    6000000.0      2023-05-31 00:00:00       TTMA
#
#                                            image_url  \
# 0  https://img.a.transfermarkt.technology/portrai...
#
#                                                  url  \
# 0  https://www.transfermarkt.co.uk/danijel-subasi...
#
#   current_club_domestic_competition_id current_club_name
# 0                                  FR1         AS Monaco

# %%
#21c
data.iloc[100:150]
# Out:
#                     name  last_season  current_club_id          player_code  \
# 100         Luka Zahovic         2016              306         luka-zahovic
# 101       Orhan Ovacikli         2020              126       orhan-ovacikli
# 102        Artem Favorov         2019            16239        artem-favorov
# 103          Marius Funk         2021               65          marius-funk
# 104    Nicolas Saint-Ruf         2016              595    nicolas-saint-ruf
# 105          Jack Duncan         2015             5724          jack-duncan
# 106          Ugur Ciftci         2022             2381          ugur-ciftci
# 107         Mikey Devlin         2022              903         mikey-devlin
# 108        Lars Veldwijk         2019              468        lars-veldwijk
# 109         Álex Barrera         2015             2448         alex-barrera
# 110        Julián Cuesta         2022              605        julian-cuesta
# ...

# %%
#22 tallest player in Brazil football team

# %%
data_brazil=data[data['country_of_citizenship']=='Brazil']

# %%
data_brazil.nlargest(5,'height_in_cm')
# Out:
#                  name  last_season  current_club_id      player_code  \
# 90     Rafael Broetto         2018             1301   rafael-broetto
# 6008     Helton Leite         2022              294     helton-leite
# 568        Caio Secco         2020             1301       caio-secco
# 6725  Gabriel Barbosa         2022             2672  gabriel-barbosa
# 213   Bruno Bertinato         2021              607  bruno-bertinato
#
#      country_of_birth   city_of_birth country_of_citizenship date_of_birth  \
# 90             Brazil        Cianorte                 Brazil    1990-08-18
# 6008           Brazil  Belo Horizonte                 Brazil    1990-11-02
# 568            Brazil           Cambé                 Brazil    1990-12-22
# 6725           Brazil        Anápolis                 Brazil    1999-03-17
# 213            Brazil        Curitiba                 Brazil    1998-05-31
#
#         sub_position    position   foot  height_in_cm  market_value_in_eur  \
# ...

# %%
#23 largest market valued player of Brazil

# %%
data_brazil.nlargest(5,'market_value_in_eur')
# Out:
#                     name  last_season  current_club_id         player_code  \
# 6781  Gabriel Martinelli         2022               11  gabriel-martinelli
# 332      Bruno Guimarães         2022              762     bruno-guimaraes
# 4223   Gabriel Magalhães         2022               11   gabriel-magalhaes
# 7210       Matheus Cunha         2022              543       matheus-cunha
# 7288          João Gomes         2022              543          joao-gomes
#
#      country_of_birth   city_of_birth country_of_citizenship date_of_birth  \
# 6781           Brazil       Guarulhos                 Brazil    2001-06-18
# 332            Brazil  Rio de Janeiro                 Brazil    1997-11-16
# 4223           Brazil       São Paulo                 Brazil    1997-12-19
# 7210           Brazil     João Pessoa                 Brazil    1999-05-27
# 7288           Brazil  Rio de Janeiro                 Brazil    2001-02-12
#
# ...

# %%
#24 total market value of each club

# %%
data_CMvalue=data.groupby(['current_club_name'])['market_value_in_eur'].sum().reset_index()

# %%
data_CMvalue.sort_values(by='market_value_in_eur',ascending=False)
# Out:
#                current_club_name  market_value_in_eur
# 59                 Bayern Munich          661525000.0
# 233              Manchester City          644200000.0
# 228                 Liverpool FC          478100000.0
# 46                    Arsenal FC          446100000.0
# 354            Tottenham Hotspur          445100000.0
# ..                           ...                  ...
# 90                     Cesena FC             125000.0
# 116                   Elazigspor             125000.0
# 239  Metalurg Zaporizhya (-2016)             100000.0
# 10                     ACN Siena              50000.0
# 56                 Balikesirspor              50000.0
#
# [397 rows x 2 columns]

# %%
#25 cross tabulation of FOOT and POSITION

# %%
pd.crosstab(data.foot, data.position, margins=True)
# Out:
# position  Attack  Defender  Goalkeeper  Midfield   All
# foot
# both         120        74          27       117   338
# left         513       952         107       486  2058
# right       1581      1624         672      1731  5608
# All         2214      2650         806      2334  8004

# %%
#26 Total market value of GERMAN defenders

# %%
data_germ=data[data['country_of_citizenship']=='Germany']

# %%
data_GerCount=data_germ.groupby(['position'])['market_value_in_eur'].sum().reset_index()

# %%
data_GerCount
# Out:
#      position  market_value_in_eur
# 0      Attack          388050000.0
# 1    Defender          364500000.0
# 2  Goalkeeper          118250000.0
# 3    Midfield          495900000.0

# %%
#27 Average of total market value of german defenders

# %%
data_GerCount_Averge = data.groupby(['position'])['market_value_in_eur'].mean()

# %%
data_GerCount_Averge
# Out:
# position
# Attack        3.021335e+06
# Defender      2.769134e+06
# Goalkeeper    1.669057e+06
# Midfield      2.884507e+06
# Name: market_value_in_eur, dtype: float64

# %%
#28 Total market value of RIGHT FOOT players of FRANCE AND Argentina

# %%
data_rfoot=data.query("country_of_citizenship =='France' | country_of_citizenship =='Argentina'")

# %%
data_rfoot
# Out:
#                      name  last_season  current_club_id          player_code  \
# 2             Óscar Trejo         2022              367          oscar-trejo
# 15         Federico Fazio         2022              380       federico-fazio
# 16         Ángel Di María         2022              506       angel-di-maria
# 54       Facundo Ferreyra         2020              940     facundo-ferreyra
# 69        Pablo Chavarría         2019              237      pablo-chavarria
# ...                   ...          ...              ...                  ...
# 7965   Abdoul Kader Bamba         2022              995   abdoul-kader-bamba
# 7972        Brandon Soppy         2022              410        brandon-soppy
# 7975  Jean-Kévin Augustin         2021              995  jean-kevin-augustin
# 7978       Evann Guessand         2022              995       evann-guessand
# 7990         Nehuén Pérez         2022              410         nehuen-perez
#
# ...

# %%
data_rfootValue=data_rfoot.groupby(['foot'])['market_value_in_eur'].sum().reset_index()

# %%
data_rfootValue
# Out:
#     foot  market_value_in_eur
# 0   both         6.597500e+07
# 1   left         6.202350e+08
# 2  right         2.282725e+09

# %%
#29 from the above DF, find the total market value of, left foot-
#players of france
data_LfootFr=data_rfoot.groupby(['foot','country_of_citizenship'])['market_value_in_eur'].sum().reset_index()

# %%
data_LfootFr
# Out:
#     foot country_of_citizenship  market_value_in_eur
# 0   both              Argentina         3.157500e+07
# 1   both                 France         3.440000e+07
# 2   left              Argentina         1.982350e+08
# 3   left                 France         4.220000e+08
# 4  right              Argentina         6.697250e+08
# 5  right                 France         1.613000e+09

# %%
data_LfootFr.market_value_in_eur.sum()
# Out:
# 2968935000.0

# %%
data_rfootValue.market_value_in_eur.sum()
# Out:
# 2968935000.0

# %%
#30 new column AGE

# %%
data['AGE']=2023-pd.DatetimeIndex(data['date_of_birth']).year

# %%
data.head()
# Out:
#               name  last_season  current_club_id      player_code  \
# 0  Danijel Subasic         2019              162  danijel-subasic
# 1  Daniele Dessena         2019               19  daniele-dessena
# 2      Óscar Trejo         2022              367      oscar-trejo
# 3   Fabio Ceravolo         2019              130   fabio-ceravolo
# 4      Dusan Tadic         2022              610      dusan-tadic
#
#     country_of_birth        city_of_birth country_of_citizenship  \
# 0  Jugoslawien (SFR)                Zadar                Croatia
# 1              Italy                Parma                  Italy
# 2          Argentina  Santiago del Estero              Argentina
# 3              Italy                Locri                  Italy
# 4  Jugoslawien (SFR)         Bačka Topola                 Serbia
#
#   date_of_birth        sub_position    position  ... height_in_cm  \
# 0    1984-10-27          Goalkeeper  Goalkeeper  ...        191.0
# ...

# %%
#31 implementation of range(pd.cut), range wise value arrangement

# %%
cutoff = [0, 20, 50, 85]
labels = ['Child', 'Adult', 'Old']
data['AGE_TYPE'] = pd.cut(data.AGE, bins=cutoff, labels=labels)

# %%
data.head()
# Out:
#               name  last_season  current_club_id      player_code  \
# 0  Danijel Subasic         2019              162  danijel-subasic
# 1  Daniele Dessena         2019               19  daniele-dessena
# 2      Óscar Trejo         2022              367      oscar-trejo
# 3   Fabio Ceravolo         2019              130   fabio-ceravolo
# 4      Dusan Tadic         2022              610      dusan-tadic
#
#     country_of_birth        city_of_birth country_of_citizenship  \
# 0  Jugoslawien (SFR)                Zadar                Croatia
# 1              Italy                Parma                  Italy
# 2          Argentina  Santiago del Estero              Argentina
# 3              Italy                Locri                  Italy
# 4  Jugoslawien (SFR)         Bačka Topola                 Serbia
#
#   date_of_birth        sub_position    position  ... market_value_in_eur  \
# 0    1984-10-27          Goalkeeper  Goalkeeper  ...             50000.0
# ...

# %%
#32 pivot table of MARKET VALUE for country and position

# %%
pivot_01 = data.pivot_table(values='market_value_in_eur', index='country_of_citizenship', columns='position', aggfunc='sum')

# %%
pivot_01
# Out:
# position                     Attack     Defender  Goalkeeper     Midfield
# country_of_citizenship
# Albania                  43100000.0   25875000.0    375000.0   16825000.0
# Algeria                  60750000.0   29600000.0   2100000.0   63675000.0
# Andorra                         NaN          NaN    500000.0          NaN
# Angola                    8100000.0    7500000.0         NaN    1250000.0
# Argentina               293050000.0  268610000.0  61200000.0  276675000.0
# ...                             ...          ...         ...          ...
# Uzbekistan                8500000.0          NaN         NaN     500000.0
# Venezuela                19000000.0    3250000.0   3500000.0    5550000.0
# Wales                    53250000.0   69700000.0   6100000.0   42950000.0
# Zambia                   29150000.0          NaN         NaN     750000.0
# Zimbabwe                  4000000.0    2000000.0         NaN    9000000.0
#
# [145 rows x 4 columns]

# %%
#33 sorting the pivot table(country with highest "ATTACK" market value)
pivot_01.sort_values(by='Attack',ascending=False)
# Out:
# position                     Attack     Defender   Goalkeeper     Midfield
# country_of_citizenship
# France                  603450000.0  807825000.0  148375000.0  509750000.0
# England                 571625000.0  870250000.0  134125000.0  673625000.0
# Spain                   434400000.0  648175000.0  134300000.0  521625000.0
# Germany                 388050000.0  364500000.0  118250000.0  495900000.0
# Argentina               293050000.0  268610000.0   61200000.0  276675000.0
# ...                             ...          ...          ...          ...
# Philippines                     NaN     350000.0     850000.0          NaN
# St. Lucia                       NaN     300000.0          NaN          NaN
# Syria                           NaN     350000.0          NaN     350000.0
# Uganda                          NaN     350000.0          NaN          NaN
# United Arab Emirates            NaN      50000.0          NaN          NaN
#
# [145 rows x 4 columns]

# %%
#34 Histogram

# %%
data.last_season.plot.hist();

# %%
plt.figure(figsize=(9,6))
plt.title('Heading_LastSeason')
plt.xlabel('x axis')
plt.ylabel('y label')
plt.xticks(rotation = 45)
sns.histplot(data=data, x='last_season', bins=50)
plt.show()

# %%
#35 area chart

# %%
plt.figure(figsize=(18,5))
plt.xticks(rotation = 90)
plt.stackplot(data.last_season,data.market_value_in_eur)
plt.show()

# %%
#36 Line charts

# %%
plt.figure(figsize=(10,6))
plt.xlabel('last_season')
plt.ylabel('market_value')
plt.title('GRAPH')
sns.lineplot(data=data,x='last_season', y='market_value_in_eur')
plt.show()

# %%
#37 Scatter plot

# %%
sns.scatterplot(data=data, x='last_season', y='market_value_in_eur')
plt.show()

# %%
#38 box plot

# %%
data.last_season.plot.box(cmap ='magma')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data, x='last_season')
plt.show()

# %%
sns.boxplot(data=data, y='last_season')
plt.show()

# %%
#39 Kernel Density Estimation Plot (KDE PLOT)

# %%
sns.kdeplot(data=data.last_season)
plt.show()

# %%
#40 subplots

# %%
data.plot.box( figsize=(18,3), subplots = True);

# %%
data.plot.box(figsize = (22,5),subplots = True);

# %%
data.plot.hist( figsize=(6,12), subplots = True);

# %%
plt.figure(figsize=(18,6))
plt.xticks(rotation = 75)
sns.boxplot(data=data)
plt.show()

# %%
#41 Subplots in matplotlib

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(data=data,y='last_season')
plt.subplot(2,2,2)
sns.boxplot(data=data,y='market_value_in_eur')
plt.subplot(2,2,3)
sns.boxplot(data=data,y='highest_market_value_in_eur')
#plt.subplot(2,2,4)
#sns.boxplot(data=data,y='Horsepower')
#plt.show()
# Out:
# <AxesSubplot:ylabel='highest_market_value_in_eur'>

# %%
#Subplots using enumerate

# %%
#Let's create list in which there is only the columns which we are going to plot

# %%
data.dtypes
# Out:
# name                                      object
# last_season                                int64
# current_club_id                            int64
# player_code                               object
# country_of_birth                          object
# city_of_birth                             object
# country_of_citizenship                    object
# date_of_birth                             object
# sub_position                              object
# position                                  object
# foot                                      object
# height_in_cm                             float64
# market_value_in_eur                      float64
# highest_market_value_in_eur              float64
# contract_expiration_date                  object
# agent_name                                object
# image_url                                 object
# url                                       object
# current_club_domestic_competition_id      object
# ...

# %%
data["AGE_TYPE"] = data["AGE_TYPE"].astype("str")

# %%
data.dtypes
# Out:
# name                                     object
# last_season                               int64
# current_club_id                           int64
# player_code                              object
# country_of_birth                         object
# city_of_birth                            object
# country_of_citizenship                   object
# date_of_birth                            object
# sub_position                             object
# position                                 object
# foot                                     object
# height_in_cm                            float64
# market_value_in_eur                     float64
# highest_market_value_in_eur             float64
# contract_expiration_date                 object
# agent_name                               object
# image_url                                object
# url                                      object
# current_club_domestic_competition_id     object
# current_club_name                        object
# ...

# %%
features = []

# %%
for i in data.columns:
    if data[i].dtypes != 'object':
        features.append(i)

# %%
features
# Out:
# ['last_season',
#  'current_club_id',
#  'height_in_cm',
#  'market_value_in_eur',
#  'highest_market_value_in_eur',
#  'AGE']

# %%
plt.figure(figsize=(13,10))
for i in enumerate(features):
        plt.subplot(4,3,i[0]+1)
        sns.boxplot(data=data, y=i[1], color='red')

# %%
#42 Count plot

# %%
plt.figure(figsize=(16,5))
plt.xticks(rotation = 90)
sns.countplot(data=data,x='last_season')
plt.show()

# %%
#43 Horizontal bar chart

# %%
plt.figure(figsize=(6,12))
plt.xticks(rotation = 90)
sns.barplot(data=data, x='market_value_in_eur', y='position')
plt.show()

# %%
#44 Vertical Bar plot

# %%
plt.figure(figsize=(12,4))
plt.xticks(rotation = 90)
sns.barplot(data=data, x='last_season', y='market_value_in_eur')
plt.show()

# %%
#45 Pie chart

# %%
data.position.value_counts().plot.pie(autopct ='%1.2f%%', legend = True);

# %%
palette_color = sns.color_palette('dark')

# %%
plt.pie(data=data,\
 x=data.foot.value_counts(),\
 colors=palette_color,\
 labels=['right', 'left','both'],\
 autopct='%0.2f%%');

# %%
#46 Correlation matrix or Heatmap

# %%
sns.heatmap(data.corr())
plt.show()

# %%
#More cooler approach

# %%
sns.heatmap(data.corr()[["last_season"]].sort_values(by="last_season", ascending=False), vmin=-1, vmax=1,annot=True, cmap="Greens")
plt.plot();

# %%
#47 Regplot

# %%
sns.regplot(data = data, x = 'last_season', y= 'market_value_in_eur')
plt.show()

# %%
#48 Relplo

# %%
sns.relplot(data = data, x = 'last_season', y= 'market_value_in_eur', size='highest_market_value_in_eur')
plt.show()

# %%
#49 Catplot

# %%
sns.catplot(data = data, x = 'last_season', y= 'market_value_in_eur')
plt.show()

# %%
#50 Boxen plot

# %%
sns.boxenplot(data=data, y='last_season')
plt.show()

# %%
#51 violin plot

# %%
sns.violinplot(data=data, y='last_season')
plt.show()

# %%
#52 Joint plot

# %%
sns.jointplot(data = data, x = 'last_season', y= 'market_value_in_eur')
plt.show()

# %%
sns.jointplot(data = data, x = 'last_season', y= 'market_value_in_eur', kind='hex')
plt.show()
